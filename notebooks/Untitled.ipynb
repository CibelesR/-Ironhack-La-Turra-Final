# %% [markdown]
# # Web Scraping
#
# #### La información obtenida de Open Food Facts será completada con la información real de Abril de 2020 sobre precios de estos mismos alimentos.

# %%
import requests
import pandas as pd

# %%
df = pd.read_csv('/Users/Natalio/Desktop/Cibeles/Ironhack/Proyecto_Final/Recursos/spain_openfoodfacts_products.csv', sep='\t')
df.head(3)
code = df['code'].to_list()
code
filter_qc = df[df['code'] == '5449000000996']
filter_qc
# Out:
# The history saving thread hit an unexpected error (OperationalError('unable to open database file')).History will not be written to the database.
# Empty DataFrame
# Columns: [code, url, product_name, generic_name, brands, categories_en, origins, manufacturing_places, labels, first_packaging_code_geo, purchase_places, stores, countries, allergens, traces_en, serving_size, serving_quantity, additives_tags, additives_en, nutriscore_score, nutriscore_grade, nova_group, pnns_groups_1, pnns_groups_2, states_en, main_category_en, image_url, image_nutrition_url]
# Index: []
#
# [0 rows x 28 columns]

# %%
url = 'https://www.dia.es/compra-online/'
html = requests.get(url).content
html
# Out:
# b'<!DOCTYPE html>\r\n<html lang="es">\r\n<head>\r\n\r\n    <!-- Necesario dado que hay slots que solo cargan cuando se usa un dispositivo mobile, y no son editables desde SE\r\n         a menos que se cargue la pagina mobile. Cuando los componentes sean responsive, todo el codigo marcado *SEMR*\r\n         se puede borrar -->\r\n    <!-- SEMR -->\r\n    <title>\r\n\t\tSupermercado online | &iexcl;Recibe tu compra hoy mismo! | DIA</title>\r\n\r\n\t<script type=\'text/javascript\'>\r\n\t\t\tvar _conv_page_type = "home";\r\n\t\t</script>\r\n\t\t<script type="text/javascript" src="//cdn-3.convertexperiments.com/js/10014081-10015738.js"></script>\r\n\t\t<meta http-equiv="Content-Type" content="text/html; charset=utf-8"/>\r\n\r\n\t<meta name="description" content="Supermercado online DIA: Haz la compra sin moverte de casa en nuestro s\xc3\xbaper online con entrega en el mismo d\xc3\xada y env\xc3\xado gratis a partir de 50\xe2\x82\xac, para que puedas tener r\xc3\xa1pidamente en casa todo 
# ...
